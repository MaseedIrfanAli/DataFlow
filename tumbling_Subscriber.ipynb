# %% [markdown]
# <a href="https://colab.research.google.com/github/MaseedIrfanAli/DataFlow/blob/main/tumbling_Subscriber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install google-cloud-pubsub

from google.cloud import pubsub_v1
import time
import os

serviceAccount = '/content/hadoop-431116-4cf85cb9d3ff.json'
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= serviceAccount

subscription_path = 'projects/hadoop-431116/subscriptions/rating_count_window-sub'
subscriber = pubsub_v1.SubscriberClient()

def callback(message):
  print(('Recieved Message: {}'.format(message)))
  message.ack()

subscriber.subscribe(subscription_path,callback=callback)

while True:
  time.sleep(1)
# Out:
# ...
# Recieved Message: Message {
#   data: b'1 rating for movieId 1 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# Recieved Message: Message {
#   data: b'1 rating for movieId 160 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }Recieved Message: Message {
#   data: b'1 rating for movieId 165 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
#
# Recieved Message: Message {
#   data: b'1 rating for movieId 168 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# Recieved Message: Message {
#   data: b'1 rating for movieId 172 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# Recieved Message: Message {
#   data: b'1 rating for movieId 173 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# Recieved Message: Message {
#   data: b'1 rating for movieId 175 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# Recieved Message: Message {
#   data: b'1 rating for movieId 3147 in 5 seconds'
#   ordering_key: ''
#   attributes: {}
# }
# ...
